# %%
"""
24MBD026 Musab Shaikh Parvez
A simple script to perform sentiment analysis on the 'Haathi Mere Saathi'
movie reviews, similar to the provided example.

It uses TextBlob to analyze sentiment and Matplotlib to create a bar chart.
"""

# %%
# Section 1: Import Libraries
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
# Define column names for clarity, as the original CSV has long questions as headers.
COLUMN_NAMES = [
    'overall_rating', 'plot_review', 'rajesh_khanna_rating', 'tanuja_rating',
    'bond_review', 'conflict_review', 'music_review', 'final_thoughts'
]

# Load the dataset from the CSV file
df = pd.read_csv('Haathi_Mera_Saathi_Movie_Review.csv', header=0, names=COLUMN_NAMES)
print("Dataset loaded successfully.")

# %%
# Section 3: Analyze Sentiment using TextBlob

def get_sentiment(text):
    """
    Analyzes text using TextBlob and returns a sentiment label based on polarity.
    - Polarity > 0.05 is Positive
    - Polarity < -0.05 is Negative
    - Otherwise, it's Neutral
    """
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0.05:
        return "Positive"
    elif polarity < -0.05:
        return "Negative"
    else:
        return "Neutral"

# Apply the function to create a 'Sentiment' column
df = df.apply(get_sentiment)

# Display the first few rows with the combined text and predicted sentiment
print("\nAnalysis Results:")
print(df.head())


# Section 4: Visualize the Results

print("\nGenerating sentiment distribution plot...")

# Get the counts of each sentiment category
sentiment_counts = df.value_counts()

# Create a bar chart
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['green', 'red', 'gray'])

# Add titles and labels
plt.title('Sentiment Distribution of Movie Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Responses')
plt.xticks(rotation=0)  # Keep the x-axis labels horizontal
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()
# Out:
# Dataset loaded successfully.
#
# Analysis Results:
# 0    Positive
# 1     Neutral
# 2    Positive
# 3    Positive
# 4    Negative
# dtype: object
#
# Generating sentiment distribution plot...
